# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 24})

# %%
Nt0 = 180 #Dividing n theta into 180 grid of 180
Nr = 250 #Radial direction as grid of Nr

X1 = np.linspace(0,0.55,Nr)
delt = np.pi*(2/(1+np.exp(-8*X1**(1.32)))-1)

t0_grid = np.linspace(0,2*np.pi,Nt0)
dt0 = t0_grid[1]-t0_grid[0]

X = np.linspace(0,10,Nr)

# %%
##All sky uniform

# %%
I = np.loadtxt("IzR13.csv", delimiter=",")
print(np.max(I*124.5)*1e-9)
# Out:
# 6.530882742968503

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 20})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,8))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*125, cmap='jet', linewidth=2,vmin=-6.6*1e9,vmax=6.6*1e9) # Set linewidth for bold lines

# Add a colorbar
#cbar = fig.colorbar(cax)

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IzR13.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
I = np.loadtxt("IxR13.csv", delimiter=",")

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 20})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,8))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*124.5, cmap='jet', linewidth=2,vmin=-6.6*1e9,vmax=6.6*1e9)  # Set linewidth for bold lines

# Add a colorbar
#cbar = fig.colorbar(cax)

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IxR13.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
I = np.loadtxt("IyR13.csv", delimiter=",")

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 20})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,8))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*124.5, cmap='jet', linewidth=2,vmin=-6.6*1e9,vmax=6.6*1e9)  # Set linewidth for bold lines

# Add a colorbar
#cbar = fig.colorbar(cax)

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IyR13.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 36})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,8))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*124.5, cmap='jet', linewidth=2,vmin=-6.6*1e9,vmax=6.6*1e9)  # Set linewidth for bold lines

# Add a colorbar
cbar = fig.colorbar(cax, orientation='horizontal',location='top')
cbar.set_ticks([-6.6*1e9,-3.3*1e9,0,3.3*1e9,6.6*1e9])

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IBar2.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
#All sky non uniform zero volts

# %%
I = np.loadtxt("IzR11.csv", delimiter=",")

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 36})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,14))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,0*I*124.5, cmap='jet', linewidth=2,vmin=0,vmax=6.6*1e9)  # Set linewidth for bold lines

# Add a colorbar
#cbar = fig.colorbar(cax)

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IzR11.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
I = np.loadtxt("IxR11.csv", delimiter=",")

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 20})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,8))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*124.5, cmap='jet', linewidth=2,vmin=-6.3*1e10,vmax=6.3*1e10)   # Set linewidth for bold lines

# Add a colorbar
#cbar = fig.colorbar(cax)

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IxR11.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
I = np.loadtxt("IyR11.csv", delimiter=",")

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 20})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,8))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*125, cmap='jet', linewidth=2,vmin=-6.3*1e10,vmax=6.3*1e10)  # Set linewidth for bold lines

# Add a colorbar
#cbar = fig.colorbar(cax)

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IyR11.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
# All sky non uniform 10 mV
print(np.max(I)*124.5*1e-9)
# Out:
# 61.41798006560731

# %%
I = np.loadtxt("IzR12.csv", delimiter=",")

# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 36})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,14))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*124.5, cmap='jet', linewidth=2,vmin=-5*1e9,vmax=5*1e9)  # Set linewidth for bold lines

# Add a colorbar
#cbar = fig.colorbar(cax)

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IzR12.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
I = np.loadtxt("IxR12.csv", delimiter=",")

# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 20})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,8))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*124.5, cmap='jet', linewidth=2,vmin=-6.3*1e10,vmax=6.3*1e10)   # Set linewidth for bold lines

# Add a colorbar
#cbar = fig.colorbar(cax)

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IxR12.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
I = np.loadtxt("IyR12.csv", delimiter=",")

# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 20})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,8))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*124.5, cmap='jet', linewidth=2,vmin=-6.3*1e10,vmax=6.3*1e10)   # Set linewidth for bold lines

# Add a colorbar
#cbar = fig.colorbar(cax)

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IyR12.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 20})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,8))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*124.5, cmap='jet', linewidth=2,vmin=-5*1e9,vmax=5*1e9)  # Set linewidth for bold lines

# Add a colorbar
cbar = fig.colorbar(cax, orientation='horizontal',location='top')
cbar.set_ticks([-6.4*1e10,-3.2*1e10,0,3.2*1e10,6.4*1e10])

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IYB.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 36})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,14))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*124.5, cmap='jet', linewidth=2,vmin=-5*1e9,vmax=5*1e9)   # Set linewidth for bold lines

# Add a colorbar
cbar = fig.colorbar(cax, orientation='horizontal',location='top')
cbar.set_ticks([-5*1e9,-2.5*1e9,0,2.5*1e9,5*1e9])

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IRRB.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 36})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,14))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,I*249, cmap='jet', linewidth=2,vmin=0,vmax=6.6*1e9)  # Set linewidth for bold lines

# Add a colorbar
cbar = fig.colorbar(cax, orientation='horizontal',location='top')
cbar.set_ticks([0,2.2*1e9,4.4*1e9,6.6*1e9])

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IZB.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()

# %%
#Radius figures

# %%
I1 = np.loadtxt("IzRU12.csv", delimiter=",")*249/2
I2 = np.loadtxt("IzRU6.csv", delimiter=",")*249/2
I3 = np.loadtxt("IzRN12.csv", delimiter=",")*249/2
I4 = np.loadtxt("IzRN6.csv", delimiter=",")*249/2

# %%
Nt0 = 180 #Dividing n theta into 180 grid of 180
Nr = 250 #Radial direction as grid of Nr

X1 = np.linspace(0,0.55,Nr)
delt = np.pi*(2/(1+np.exp(-8*X1**(1.32)))-1)

t0_grid = np.linspace(0,2*np.pi,Nt0)
dt0 = t0_grid[1]-t0_grid[0]

X = np.linspace(0,1,Nr)

# %%
# Load your data
#I_anti = np.loadtxt("I_par.csv")
#I_par = np.loadtxt("I_anti.csv")

x = X
y2 = I1
y1 = I2

# Configure font settings
plt.rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 30})

# Create a figure with a white background
fig = plt.figure(figsize=(10, 8))
fig.patch.set_facecolor('white')

# Plot the data and set line properties
cp, = plt.plot(x, y1, label='P', color='b', linewidth=3)
cn, = plt.plot(x, y2, label='AP', color='r', linewidth=3, zorder=3)

# Set labels and title
plt.xlabel('Radial Distance/Radius', fontweight='bold', fontsize=36)
plt.ylabel('Spin Current $I_z$ (A/m²)', fontweight='bold', fontsize=36)

# Set custom axis limits and tick positions
x_min, x_max = 0,1
y_min, y_max = -8*1e9,8*1e9
x_ticks = [0, 0, 0.1, 0.2]
y_ticks = [-8*1e9,-4*1e9,0,4*1e9,8*1e9]

#plt.xticks(x_ticks)
plt.yticks(y_ticks)
plt.xlim(x_min, x_max)
#plt.ylim(y_min, y_max)

# Create a legend without a box outline
lgd = plt.legend([cp, cn], ['6nm', '12nm'])
lgd.set_frame_on(False)

# Customize tick parameters and spines
plt.gca().tick_params(axis='both', which='major', width=3)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)

plt.tight_layout()
plt.savefig('SpinUni.png')

# Show the plot
plt.show()

# %%
# Load your data
#I_anti = np.loadtxt("I_par.csv")
#I_par = np.loadtxt("I_anti.csv")

x = X
y2 = I3
y1 = I4

# Configure font settings
plt.rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 30})

# Create a figure with a white background
fig = plt.figure(figsize=(10, 8))
fig.patch.set_facecolor('white')

# Plot the data and set line properties
cp, = plt.plot(x, y1, label='P', color='b', linewidth=3)
cn, = plt.plot(x, y2, label='AP', color='r', linewidth=3, zorder=3)

# Set labels and title
plt.xlabel('Radial Distance/Radius', fontweight='bold', fontsize=36)
plt.ylabel('Spin Current $I_z$ (A/m²)', fontweight='bold', fontsize=36)

# Set custom axis limits and tick positions
x_min, x_max = 0,1
y_min, y_max = -8*1e9,8*1e9
x_ticks = [0, 0, 0.1, 0.2]
y_ticks = [-8*1e9,-4*1e9,0,4*1e9,8*1e9]

#plt.xticks(x_ticks)
plt.yticks(y_ticks)
plt.xlim(x_min, x_max)
#plt.ylim(y_min, y_max)

# Create a legend without a box outline
lgd = plt.legend([cp, cn], ['6nm', '12nm'])
lgd.set_frame_on(False)

# Customize tick parameters and spines
plt.gca().tick_params(axis='both', which='major', width=3)
plt.gca().spines['top'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)
plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['right'].set_linewidth(2)

plt.tight_layout()
plt.savefig('SpinNon.png')

# Show the plot
plt.show()

# %%
# Create figure and axes
rcParams['font.weight'] = 'bold'
plt.rcParams.update({'font.size': 36})  # Increase font size

# Create the figure and axis with larger font size
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(10,14))


# Create the colored polar plot with bold lines
cax = ax.pcolormesh(t0_grid, X,0*I*124.5, cmap='jet', linewidth=2,vmin=-6.6*1e9,vmax=6.6*1e9)  # Set linewidth for bold lines

# Add a colorbar
#cbar = fig.colorbar(cax)

# Set title with a different font size
title_font = {'fontsize': 22, 'fontweight': 'bold'}
#ax.set_title('Spin Current Iy (A/m²)', **title_font)

# Remove degree labels
ax.set_xticklabels([])
ax.set_yticklabels([])

# Save the figure with higher DPI for better quality
plt.savefig('IzRRR.png', dpi=300,bbox_inches='tight')

# Show the plot
plt.show()
